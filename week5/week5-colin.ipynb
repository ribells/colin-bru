# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"market":"CNY","function":"DIGITAL_CURRENCY_WEEKLY","symbol":"ETH"}

headers = {
	"X-RapidAPI-Key": "4fdf7b0e21msh4e17b550c54d8d8p17665cjsn0d5ee1f96b6e",
	"X-RapidAPI-Host": "alpha-vantage.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Weekly Prices and Volumes for Digital Currency",
#         "2. Digital Currency Code": "ETH",
#         "3. Digital Currency Name": "Ethereum",
#         "4. Market Code": "CNY",
#         "5. Market Name": "Chinese Yuan",
#         "6. Last Refreshed": "2022-09-08 00:00:00",
#         "7. Time Zone": "UTC"
#     },
#     "Time Series (Digital Currency Weekly)": {
#         "2022-09-08": {
#             "1a. open (CNY)": "11003.38721700",
#             "1b. open (USD)": "1579.29000000",
#             "2a. high (CNY)": "11756.62202000",
#             "2b. high (USD)": "1687.40000000",
#             "3a. low (CNY)": "10385.87541800",
#             "3b. low (USD)": "1490.66000000",
#             "4a. close (CNY)": "11268.56265500",
#             "4b. close (USD)": "1617.35000000",
#             "5. volume": "2416163.79330000",
#             "6. market cap (USD)": "2416163.79330000"
#         },
#         "2022-09-04": {
# ...

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"interval":"5min","function":"TIME_SERIES_INTRADAY","symbol":"MSFT","datatype":"json","output_size":"compact"}

headers = {
	"X-RapidAPI-Key": "4fdf7b0e21msh4e17b550c54d8d8p17665cjsn0d5ee1f96b6e",
	"X-RapidAPI-Host": "alpha-vantage.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Intraday (5min) open, high, low, close prices and volume",
#         "2. Symbol": "MSFT",
#         "3. Last Refreshed": "2022-09-07 20:00:00",
#         "4. Interval": "5min",
#         "5. Output Size": "Compact",
#         "6. Time Zone": "US/Eastern"
#     },
#     "Time Series (5min)": {
#         "2022-09-07 20:00:00": {
#             "1. open": "258.1200",
#             "2. high": "258.1200",
#             "3. low": "258.1200",
#             "4. close": "258.1200",
#             "5. volume": "679"
#         },
#         "2022-09-07 19:55:00": {
#             "1. open": "258.1500",
#             "2. high": "258.1700",
#             "3. low": "258.1500",
#             "4. close": "258.1500",
#             "5. volume": "472"
#         },
#         "2022-09-07 19:50:00": {
#             "1. open": "258.2100",
#             "2. high": "258.2100",
#             "3. low": "258.1700",
#             "4. close": "258.1700",
# ...
